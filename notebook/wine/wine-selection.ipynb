# %% [markdown]
# # Wine Selection
#
# ## Framing
# I want to buy a fine wine but I have no idea about wine selection.I'm not good at wine tasting.
#
# I will use the data and understand what goes into making fine wine

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (13,8)

# %%
df = pd.read_csv("./winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# ## Wine Category
# Let's create a new column 'category' which signifies the category of wine - High (1) or Low (0)
#
# Wine with quality > 6 is considered to be High quality, rest are Low quality

# %%
#df.loc[df.b > 0, 'd'] = 1
df.loc[df.quality > 5, 'category'] = 1
df.loc[df.quality <= 5, 'category'] = 0

# %% [markdown]
# This is the frequency count for each category

# %%
df.category.value_counts()
# Out:
# 1.0    855
# 0.0    744
# Name: category, dtype: int64

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  category
# 0      9.4        5       0.0
# 1      9.8        5       0.0
# 2      9.8        5       0.0
# 3      9.8        6       1.0
# 4      9.4        5       0.0

# %% [markdown]
# ## Visual Exploration
#
# Let's see how the columns are related
#
# To start, lets take 2 variables at a time to explore data

# %% [markdown]
# #### Correlation
# ![](../img/corr.svg)

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
# category                   0.095093         -0.321441     0.159129
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
# category                   -0.002160  -0.109494            -0.061757
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
# category                         -0.231963 -0.159110 -0.003264   0.218072
#
#                        alcohol   quality  category
# fixed acidity        -0.061668  0.124052  0.095093
# volatile acidity     -0.202288 -0.390558 -0.321441
# citric acid           0.109903  0.226373  0.159129
# residual sugar        0.042075  0.013732 -0.002160
# chlorides            -0.221141 -0.128907 -0.109494
# free sulfur dioxide  -0.069408 -0.050656 -0.061757
# total sulfur dioxide -0.205654 -0.185100 -0.231963
# density              -0.496180 -0.174919 -0.159110
# pH                    0.205633 -0.057731 -0.003264
# sulphates             0.093595  0.251397  0.218072
# alcohol               1.000000  0.476166  0.434751
# quality               0.476166  1.000000  0.848279
# category              0.434751  0.848279  1.000000

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(df, figsize=(15,15), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11023e198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11045e4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1103a6320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1102b3550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1103b0470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110338748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11037eeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11285a978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1128a88d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112b0a898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112b50cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112b95358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112be0390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x112bf8978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112c68668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112cb46a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112cf29b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112e41438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112cc3748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112ebd6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112ede048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112f44208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112f8c978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112fcad68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113116da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113151c88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11319ceb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113166828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11322b6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113271c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1132b6240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113405198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11343e048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1134863c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1134c4ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113511a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113529cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113597dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1135e5e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x113729160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113770ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1137ab8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1137f7b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1137c81d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114073c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1140c7940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114100748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114147eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11418c9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1141db518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11441a470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114460be0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1144b19b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1144e9f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11453a5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114578438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1145c4470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114701358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11474c588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114718048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1147d2d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1148202e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11485d8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1148ac828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1148e56d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x114b2ea58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114b73198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114bc00f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114bd52e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114c359b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114c85438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114cc4470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114e104a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114e4a390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114e965c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114e60080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11501dd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11506a320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1150a8908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1150f6860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11512f710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115179a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1151bb1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115209128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11521f3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1152904e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1152db518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11541c828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1154692b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11549cf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1154f0208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1154bb588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1157769b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1157bef28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1157f64e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11604b0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1160804e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1160c5d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116202f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116253710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1162a54e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1162dda58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11632d0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116364f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1163b1f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1163eee48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1164400b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116409978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1164c6860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11660ddd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116652400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11669f358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1166d9208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116722588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116760c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1167abbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1167c7b00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x116931f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11697ffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1169c3320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116a09d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116a45a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116a93cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116a5a4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116d1e4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116d65a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116d93f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116de7940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116e1df60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116e697f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x116ea9a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116ef71d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116f41f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116f82518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116fc9b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1171099e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117155a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117191908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1171dbb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1171ac978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117368320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1173b0898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1173eee80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11743bdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117476c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1174c4048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117602748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11764f6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117666ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1176d6a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117723a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117762da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1177ad828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1177ea550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117935780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117900518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1179bcf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a094e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a48ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a96a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117acf8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d17c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d5c390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117da92e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117dbfd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117e179b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117e6e780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ea8278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ef19e8>]], dtype=object)

# %% [markdown]
# ### Alcohol vs Category

# %%
df.plot(x="alcohol", y="category", kind="scatter")

# %% [markdown]
# #### Exercise: Volatile Acidity vs Category

# %% [markdown]
# ### 3 variable visualization
# Let's add one more dimension to get more sense what is correlated

# %% [markdown]
# ### Alcohol vs Volatile Acidity vs Category

# %%
#df.plot(x="alcohol", y="volatile acidity", kind="scatter", c="category")
ax = df[df.category == 1].plot(x="alcohol", y="volatile acidity", kind="scatter", color="red", label="HIGH", s=100, alpha=0.5)
df[df.category == 0].plot(x="alcohol", y="volatile acidity", kind="scatter", color="green", label="LOW", s=100, alpha=0.5, ax=ax)

# %%
pd.set_option("precision",3)

# %% [markdown]
# ### Time to build a predictive model
#
# Let's build a model that can predict the category of wine, given information about alcohol content and volatile acidity

# %% [markdown]
# Building a predictive model involves training the model with historical data known as **training data**. Once we have the model trained, the model can predict labels (in this case, the category of wine) for the given features (test data)
# We have 1600 rows of the wine data, lets split this data into 80:20 ratio as training:testingg data
#
# **Why do we need to do this? **
#
# We can compare the predicted label with the actual label.
# By doing this, we can measure how accurate our model is.

# %%
df.shape

# %%
df_train = df.iloc[:1280,]
df_test = df.iloc[1280:,]

# %%
X_train = df_train["volatile acidity"]
y_train = df_train["category"]

# %%
X_test = df_test["volatile acidity"]
y_test = df_test["category"]

# %%
X_train = X_train.reshape(X_train.shape[0],1)

X_test = X_test.reshape(X_test.shape[0],1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = LogisticRegression()

# %%
logistic_model.fit(X_train, y_train)

# %%
sns.lmplot(data=df, x="alcohol", y="category", logistic=True)

# %% [markdown]
# > It’s a bird… it’s a plane… it… depends on your classifier’s threshold
# -- [Sancho McCann](https://sanchom.wordpress.com/2011/09/01/precision-recall/)

# %%
predicted = logistic_model.predict(X_test)

# %%
df_compare = pd.DataFrame()
df_compare["actual"] = y_test
df_compare["predicted"] = predicted
df_compare["volatile acidity"] = df_test["volatile acidity"]

# %%
ax=df_compare.plot(x="volatile acidity", y="actual", kind="scatter", color="blue", label="actual")
df_compare.plot(x="volatile acidity", y="predicted", kind="scatter", color="red", label="predicted", ax=ax)

# %% [markdown]
# Let's add more features - volatile acidity, sulphates, alcohol to predict the category

# %% [markdown]
# 2 variable model

# %%
df_train = df.iloc[:1280,]
df_test = df.iloc[1280:,]

# %%
X_train = df_train[["sulphates", "alcohol"]]
y_train = df_train["category"]

# %%
X_test = df_test[["sulphates", "alcohol"]]
y_test = df_test["category"]

# %%
logistic_model = LogisticRegression()

logistic_model.fit(X_train, y_train)

# %%
predicted = logistic_model.predict(X_test)

# %%
df_compare = pd.DataFrame()
df_compare["actual"] = y_test
df_compare["predicted"] = predicted
df_compare["sulphates"] = df_test["sulphates"]
df_compare["alcohol"] = df_test["alcohol"]

# %%
df_compare.head()

# %%
ax = df_compare[df_compare.actual == 1].plot(x="alcohol", y="sulphates", kind="scatter", color="red", label="HIGH", s=100, alpha=0.5)
df_compare[df_compare.actual == 0].plot(x="alcohol", y="sulphates", kind="scatter", color="green", label="LOW", s=100, alpha=0.5, ax=ax)

# %%
ax = df_compare[df_compare.predicted == 1].plot(x="alcohol", y="sulphates", kind="scatter", color="red", label="HIGH", s=100, alpha=0.5)
df_compare[df_compare.predicted == 0].plot(x="alcohol", y="sulphates", kind="scatter", color="green", label="LOW", s=100, alpha=0.5, ax=ax)

# %% [markdown]
# ### Accuracy Metrics
# * AUC
# * ROC
# * Misclassification Rate
# * Confusion Matrix
# * Precision & Recall

# %% [markdown]
# #### Confusion Matrix
#
# ![](../img/confusion-matrix.jpg)

# %% [markdown]
# #### Calculate True Positive Rate
#     TPR = TP / (TP+FN)
#
# #### Calculate False Positive Rate
#     FPR = FP / (FP+TN)

# %% [markdown]
# #### Precise & Recall

# %% [markdown]
# ### AUC-ROC for the model

# %%
from sklearn import metrics

# %%
#ols_auc = metrics.roc_auc_score(df_compare.actual, df_compare.predicted)
fpr, tpr, thresholds = metrics.roc_curve(df_compare.actual, df_compare.predicted)
plt.plot(fpr, tpr)
plt.plot([0,1],[0,1])
